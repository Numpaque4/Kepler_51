# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt('TTVplan-post_equal_weights.dat')

# %%
df = pd.DataFrame(data)

# %%
df.describe()
# Out:
#                  0             1             2           3             4   \
# count  45011.000000  45011.000000  45011.000000  45011.0000  4.501100e+04
# mean       0.474535   1879.776516      1.418980     85.3162  5.581085e+04
# std        0.290269    806.784403      0.303439      0.0000  1.455208e-11
# min        0.041227    651.427444      0.868341     85.3162  5.581085e+04
# 25%        0.206793   1374.732856      1.147333     85.3162  5.581085e+04
# 50%        0.457016   1700.686897      1.409008     85.3162  5.581085e+04
# 75%        0.730042   2157.158090      1.685397     85.3162  5.581085e+04
# max        0.999986  10750.762869      1.972682     85.3162  5.581085e+04
#
#                  5             6             7             8             9   \
# count  45011.000000  45011.000000  45011.000000  45011.000000  45011.000000
# mean       0.520434      0.508686  55043.015351  55128.316227  55213.641076
# ...

# %%
means = df.describe().loc['mean']
print(means)
# Out:
# 0         0.474535
# 1      1879.776516
# 2         1.418980
# 3        85.316200
# 4     55810.845483
# 5         0.520434
# 6         0.508686
# 7     55043.015351
# 8     55128.316227
# 9     55213.641076
# 10    55298.953302
# 11    55384.261835
# 12    55469.567993
# 13    55725.517386
# 14    55810.835226
# 15    55896.148993
# 16    55981.462613
# 17    56066.806425
# 18    56152.111202
# 19    56237.615738
# 20    56322.754142
# 21    56408.069555
# 22    53892.190693
# Name: mean, dtype: float64

# %%
df[1]
# Out:
# 0         814.793702
# 1        3042.637492
# 2        2174.741394
# 3        2143.870451
# 4        2353.984068
#             ...
# 45006    1382.471257
# 45007    1489.190017
# 45008     973.673737
# 45009    1219.897394
# 45010    1692.883220
# Name: 1, Length: 45011, dtype: float64

# %%
plt.hist(df[1],bins=1000,density=True);

# %%
plt.hist(df[0],bins=100,density=True);

# %%
plt.hist(df[2],bins=100,density=True);

# %%
len(df)
# Out:
# 45011
